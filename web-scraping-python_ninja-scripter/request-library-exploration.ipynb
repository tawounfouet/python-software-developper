# %%
import requests

r = requests.get('https://api.github.com/events')
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'application/json; charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '[{"id":"27874881938","type":"WatchEvent","actor":{"id":9982233,"login":"changhefirst","display_login":"changhefirst","gravatar_id":"","url":"https://api.github.com/users/changhefirst","avatar_url":"https://avatars.githubusercontent.com/u/9982233?"},"repo":{"id":613591358,"name":"tloen/alpaca-lora","url":"https://api.github.com/repos/tloen/alpaca-lora"},"payload":{"action":"started"},"public":true,"created_at":"2023-03-21T15:30:05Z"},{"id":"27874880446","type":"PublicEvent","actor":{"id":45582505,"login":"hustvl","display_login":"hustvl","gravatar_id":"","url":"https://api.github.com/users/hustvl","avatar_url":"https://avatars.githubusercontent.com/u/45582505?"},"repo":{"id":602453355,"name":"hustvl/VAD","url":"https://api.github.com/repos/hustvl/VAD"},"payload":{},"public":true,"created_at":"2023-03-21T15:30:03Z","org":{"id":45582505,"login":"hustvl","gravatar_id":"","url":"https://api.github.com/orgs/hustvl","avatar_url":"https://avatars.githubusercontent.com/u/45582505?"}},{"id":"27874881901","type":"PullRequestEvent","actor":{"id":10810283,"login":"direwolf-github","display_login":"direwolf-github","gravatar_id":"","url":"https://api.github.com/users/direwolf-github","avatar_url":"https://avatars.githubusercontent.com/u/10810283?"},"repo":{"id":617041371,"name":"direwolf-github/ephemeral-ci-56c41f49","url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-56c41f49"},"payload":{"action":"opened","number":1,"pull_request":{"url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-56c41f49/pulls/1","id":1284456808,"node_id":"PR_kwDOJMdN285Mj0Fo","html_url":"https://github.com/direwolf-github/ephemeral-ci-56c41f49/pull/1","diff_url":"https://github.com/direwolf-github/ephemeral-ci-56c41f49/pull/1.diff","patch_url":"https://github.com/direwolf-github/ephemeral-ci-56c41f49/pull/1.patch","issue_url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-56c41f49/issues/1","number":1,"state":"open","locked":false,"title":"Direwolf review apps test branch-f934bfd1","user":{"login":"direwolf-github","id":10810283,"node_id":"MDQ6VXNlcjEwODEwMjgz","avatar_url":"https://avatars.githubusercontent.com/u/10810283?v=4","gravatar_id":"","url":"https://api.github.com/users/direwolf-github","html_url":"https://github.com/direwolf-github","followers_url":"https://api.github.com/users/direwolf-github/followers","following_url":"https://api.github.com/users/direwolf-github/following{/other_user}","gists_url":"https://api.github.com/users/direwolf-github/gists{/gist_id}","starred_url":"https://api.github.com/users/direwolf-github/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/direwolf-github/subscriptions","organizations_url":"https://api.github.com/users/direwolf-github/orgs","repos_url":"https://api.github.com/users/direwolf-github/repos","events_url":"https://api.github.com/users/direwolf-github/events{/privacy}","received_events_url":"https://api.github.com/users/direwolf-github/received_events","type":"User","site_admin":false},"body":"Direwolf review apps test branch-f934bfd1","created_at":"2023-03-21T15:30:04Z","updated_at":"2023-03-21T15:30:04Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-56c41f49/pulls/1/commits","review_comments_url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-56c41f49/pulls/1/comments","review_comment_url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-56c41f49/pulls/comments{/number}","comments_url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-56c41f49/issues/1/comments","statuses_url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-56c41f49/statuses/9c16576fd0b052a31c5e33383cb033156a871270","head":{"label":"direwolf-github:branch-f934bfd1","ref":"branch-f934bfd1","sha":"9c16576fd0b052a31c5e33383cb033156a871270","user ...

# %%
r.json()[0]
# Out:
# {'id': '27874881938',
#  'type': 'WatchEvent',
#  'actor': {'id': 9982233,
#   'login': 'changhefirst',
#   'display_login': 'changhefirst',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/changhefirst',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/9982233?'},
#  'repo': {'id': 613591358,
#   'name': 'tloen/alpaca-lora',
#   'url': 'https://api.github.com/repos/tloen/alpaca-lora'},
#  'payload': {'action': 'started'},
#  'public': True,
#  'created_at': '2023-03-21T15:30:05Z'}

# %%
r = requests.post('https://httpbin.org/post', data={'key': 'value'})
r
# Out:
# <Response [200]>

# %%
r = requests.put('https://httpbin.org/put', data={'key': 'value'})
print(r)

r.json()
# Out:
# <Response [200]>
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.28.1',
#   'X-Amzn-Trace-Id': 'Root=1-6419cfd7-4de1286c736c7bd7559e0718'},
#  'json': None,
#  'origin': '81.249.168.155',
#  'url': 'https://httpbin.org/put'}

# %%
r = requests.delete('https://httpbin.org/delete')
print(r)

r.json()
# Out:
# <Response [200]>
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.28.1',
#   'X-Amzn-Trace-Id': 'Root=1-6419cff6-0d919f0b5feaa7cd787391bc'},
#  'json': None,
#  'origin': '81.249.168.155',
#  'url': 'https://httpbin.org/delete'}

# %%
r = requests.head('https://httpbin.org/get')
print(r, "\n")
print(r.headers, "\n")
print(r.text)
# Out:
# <Response [200]>
#
# {'Date': 'Tue, 21 Mar 2023 15:43:02 GMT', 'Content-Type': 'application/json', 'Content-Length': '312', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
r = requests.options('https://httpbin.org/get')

print(r, "\n")
print(r.headers, "\n")
print(r.text)
# Out:
# <Response [200]>
#
# {'Date': 'Tue, 21 Mar 2023 15:43:47 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '0', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Allow': 'GET, OPTIONS, HEAD', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET, POST, PUT, DELETE, PATCH, OPTIONS', 'Access-Control-Max-Age': '3600'}

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)
print(r)

r.json()
# Out:
# <Response [200]>
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.28.1',
#   'X-Amzn-Trace-Id': 'Root=1-6419d13a-06b2db9c7a4ede42466c8aaf'},
#  'origin': '81.249.168.155',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text


from PIL import Image
from io import BytesIO

i = Image.open(BytesIO(r.content))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[39], line 10
#       7 from PIL import Image
#       8 from io import BytesIO
# ---> 10 i = Image.open(BytesIO(r.content))
#
# File ~/miniconda3/lib/python3.10/site-packages/PIL/Image.py:3283, in open(fp, mode, formats)
#    3281     warnings.warn(message)
#    3282 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3283 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x7f854f272110>
